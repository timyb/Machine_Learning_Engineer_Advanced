# %% [markdown]
# <h1>Clustering Features<h1>

# %%
# Clustering_2
# %run k_means_cluster.py

# %% [markdown]
# <h1>Clustering with 3 Features<h1>

# %%
# Clustering_2
# %run k_means_cluster.py

# %% [markdown]
# <h1>Stock Option Range<h1>

# %%
# Calculating the max and min for exercised_stock_options
max_stock_value = max(item['exercised_stock_options'] for item in data_dict.values() if item['exercised_stock_options'] != 'NaN')
min_stock_value = min(item['exercised_stock_options'] for item in data_dict.values())
print(max_stock_value, min_stock_value)
# Out:
# (34348384, 3285)

# %% [markdown]
# <h1>Salary Range<h1>

# %%
# Calculating the max and min for salary
max_salary = max(item['salary'] for item in data_dict.values() if item['salary'] != 'NaN')
min_salary = min(item['salary'] for item in data_dict.values())
print(max_salary, min_salary)
# Out:
# (1111258, 477)
